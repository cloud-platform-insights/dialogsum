# %% [markdown]
# # ROUGE (Recall-oriented Understudy of Gisting Evaluation)

# %% [markdown]
# ## Install packages

# %%
# !pip install evaluate
# !pip install rouge-score
# !pip install pandas
# Out:
# Requirement already satisfied: evaluate in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (0.4.2)
# Requirement already satisfied: datasets>=2.0.0 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from evaluate) (2.19.1)
# Requirement already satisfied: numpy>=1.17 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from evaluate) (4.66.4)
# Requirement already satisfied: xxhash in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.3.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from evaluate) (0.23.0)
# Requirement already satisfied: packaging in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from evaluate) (24.0)
# Requirement already satisfied: filelock in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (3.14.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (16.0.0)
# Requirement already satisfied: pyarrow-hotfix in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (3.9.5)
# Requirement already satisfied: pyyaml>=5.1 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Requirement already satisfied: rouge-score in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (0.1.2)
# Requirement already satisfied: absl-py in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from rouge-score) (2.1.0)
# Requirement already satisfied: nltk in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from rouge-score) (3.8.1)
# Requirement already satisfied: numpy in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from nltk->rouge-score) (2024.5.10)
# Requirement already satisfied: tqdm in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from nltk->rouge-score) (4.66.4)
# Requirement already satisfied: pandas in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/rgmartinez/Desktop/dialogsum/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# ## Load the rouge metric

# %%
import evaluate
rouge = evaluate.load("rouge")

# %% [markdown]
# ## Provide predictions and references

# %% [markdown]
# ### Sample of `rouge.compute`

# %%
# ['prompt1 tuned response', 'prompt2 tuned response']
sample_predictions = ['the cow jumped over the moon', 'the dish ran away with the spoon']
# [ ['prompt1 reference response 1', 'prompt1 reference response 2'], ['prompt2 reference response 1', 'prompt2 reference repsonse 2'] ]
sample_references = [['the cow lept over the moon', 'the cow went over the moon'], ['the plate dashed away with the spoon','the dish ran with the spoon']]

rouge.compute(predictions=sample_predictions, references=sample_references)
# Out:
# {'rouge1': 0.8782051282051282,
#  'rouge2': 0.6636363636363636,
#  'rougeL': 0.8782051282051282,
#  'rougeLsum': 0.8782051282051282}

# %% [markdown]
# ### Import CSV files

# %%
import pandas as pd

# Load the CSV files into Pandas DataFrames
reference_prompts = pd.read_csv('./gemini_core_datasets/testing.csv')
reference_prompts = reference_prompts.drop(columns=['topic1', 'topic2', 'topic3'])

model_outputs = {}

model_outputs['base_gemini'] = pd.read_csv('./tuned_results/base.gemini-1.0-pro-002.output.csv')

# model_outputs['core_sdk_small'] = pd.read_csv('./tuned_results/dev_api/tuned.sdk.small.output.csv')
# model_outputs['core_sdk_large'] = pd.read_csv('./tuned_results/dev_api/tuned.sdk.large.output.csv')
# model_outputs['studio_small'] = pd.read_csv('./tuned_results/dev_api/tuned.studio.small.output.csv')
# model_outputs['studio_large'] = pd.read_csv('./tuned_results/dev_api/tuned.studio.large.output.csv')

model_outputs['vertex_sdk_small'] = pd.read_csv('./tuned_results/vertex_api/tuned.vertex.sdk.small.output.csv')
model_outputs['vertex_sdk_large'] = pd.read_csv('./tuned_results/vertex_api/tuned.vertex.sdk.large.output.csv')
model_outputs['vertex_studio_small'] = pd.read_csv('./tuned_results/vertex_api/tuned.vertex.studio.small.output.csv')
model_outputs['vertex_studio_large'] = pd.read_csv('./tuned_results/vertex_api/tuned.vertex.studio.large.output.csv')
model_outputs['vertex_studio_large_w_validation'] = pd.read_csv('./tuned_results/vertex_api/tuned.vertex.studio.large.w.validation.output.csv')

# %%
for model_output in model_outputs:
    print(model_outputs[model_output])
# Out:
#       fname                                           dialogue  \
# 0    test_0  #Person1#: Ms. Dawson, I need you to take a di...
# 1    test_1  #Person1#: You're finally here! What took so l...
# 2    test_2  #Person1#: Kate, you never believe what's happ...
# 3    test_3  #Person1#: Happy Birthday, this is for you, Br...
# 4    test_4  #Person1#: This Olympic park is so big!\n#Pers...
# ..      ...                                                ...
# 95  test_95  #Person1#: Thank you. Steven. That was the mos...
# 96  test_96  #Person1#: Bill, how can you hear so happy tod...
# 97  test_97  #Person1#: I'd like to pay my bill now. \n#Per...
# 98  test_98  #Person1#: Carol telephone.\n#Person2#: Who is...
# 99  test_99  #Person1#: Hey, don't I know you from somewher...
#
#                                               summary
# 0   ## Intra-Office Memorandum\n\n**To:** All Empl...
# 1   #Person1#: I'm glad you've decided to stop dri...
# 2   #Person2#: Wow, this is a big news. I can't be...
# 3   #Person2#: Yes, let's go get a drink. I'm so g...
# 4   #Person1#: Wow, this Olympic park is huge!\n#P...
# ..                                                ...
# 95  ## Tipping in China: A Conversation Between Tw...
# 96  #Person1#: Really? What was the matter? \n#Per...
# 97  #Person1#: I'd like to pay my bill now. \n#Per...
# 98  ## Summary of the conversation:\n\n* **Person1...
# 99  #Person1#: Oh, hey, I know you! You're the one...
#
# [100 rows x 3 columns]
#       fname                                           dialogue  \
# 0    test_0  #Person1#: Ms. Dawson, I need you to take a di...
# 1    test_1  #Person1#: You're finally here! What took so l...
# 2    test_2  #Person1#: Kate, you never believe what's happ...
# 3    test_3  #Person1#: Happy Birthday, this is for you, Br...
# 4    test_4  #Person1#: This Olympic park is so big!\n#Pers...
# ..      ...                                                ...
# 95  test_95  #Person1#: Thank you. Steven. That was the mos...
# 96  test_96  #Person1#: Bill, how can you hear so happy tod...
# 97  test_97  #Person1#: I'd like to pay my bill now. \n#Per...
# 98  test_98  #Person1#: Carol telephone.\n#Person2#: Who is...
# 99  test_99  #Person1#: Hey, don't I know you from somewher...
#
#                                               summary
# 0   #Person1# wants #Person2# to take a dictation ...
# 1   #Person2# got stuck in traffic again. #Person1...
# 2   Kate tells #Person2# that Masha and Hero are g...
# 3   #Person1# attends Brian's birthday party and d...
# 4   #Person1# and #Person2# are visiting the Olymp...
# ..                                                ...
# 95  Lin treats Steven to a magnificent meal in Bei...
# 96  #Person2# tells #Person1# he made a move today...
# 97  Tom Wilson is checking out of the hotel and pa...
# 98  Carol is taking a shower when Susan calls. #Pe...
# 99  #Person1# thinks #Person2# is familiar but #Pe...
#
# [100 rows x 3 columns]
#       fname                                           dialogue  \
# 0    test_0  #Person1#: Ms. Dawson, I need you to take a di...
# 1    test_1  #Person1#: You're finally here! What took so l...
# 2    test_2  #Person1#: Kate, you never believe what's happ...
# 3    test_3  #Person1#: Happy Birthday, this is for you, Br...
# 4    test_4  #Person1#: This Olympic park is so big!\n#Pers...
# ..      ...                                                ...
# 95  test_95  #Person1#: Thank you. Steven. That was the mos...
# 96  test_96  #Person1#: Bill, how can you hear so happy tod...
# 97  test_97  #Person1#: I'd like to pay my bill now. \n#Per...
# 98  test_98  #Person1#: Carol telephone.\n#Person2#: Who is...
# 99  test_99  #Person1#: Hey, don't I know you from somewher...
#
#                                               summary
# 0   #Person1# asks Ms. Dawson to take a dictation ...
# 1   #Person2# got stuck in traffic again. #Person1...
# 2   #Person1# tells Kate that Masha and Hero are g...
# 3   #Person1# gives Brian a present on his birthda...
# 4   #Person1# thinks the Olympic park is big. #Per...
# ..                                                ...
# 95  Lin thanks Steven for the magnificent meal. Li...
# 96  Bill tells #Person1# he made a move today and ...
# 97  #Person2# helps Tom Wilson pay his bill with a...
# 98  #Person1# answers the phone for Carol. Carol i...
# 99  #Person1# thinks #Person2# looks familiar and ...
#
# [100 rows x 3 columns]
#       fname                                           dialogue  \
# 0    test_0  #Person1#: Ms. Dawson, I need you to take a di...
# 1    test_1  #Person1#: You're finally here! What took so l...
# 2    test_2  #Person1#: Kate, you never believe what's happ...
# 3    test_3  #Person1#: Happy Birthday, this is for you, Br...
# 4    test_4  #Person1#: This Olympic park is so big!\n#Pers...
# ..      ...                                                ...
# 95  test_95  #Person1#: Thank you. Steven. That was the mos...
# 96  test_96  #Person1#: Bill, how can you hear so happy tod...
# 97  test_97  #Person1#: I'd like to pay my bill now. \n#Per...
# 98  test_98  #Person1#: Carol telephone.\n#Person2#: Who is...
# 99  test_99  #Person1#: Hey, don't I know you from somewher...
#
#                                               summary
# 0   #Person1# asks Ms. Dawson to take a dictation ...
# 1   #Person2# tells #Person1# about the terrible t...
# 2   Kate can't believe Masha and Hero are getting ...
# 3   Brian invites #Person1# to his birthday party....
# 4   #Person1# and #Person2# are in the Olympic sta...
# ..                                                ...
# 95  Steven treats Lin a meal abroad, and Lin intro...
# 96  Bill tells #Person1# he made a move today to B...
# 97       #Person1# pays #Person2# for the hotel bill.
# 98  Susan calls Carol but Carol is taking a shower...
# 99  #Person1# thinks #Person2# looks familiar and ...
#
# [100 rows x 3 columns]
#       fname                                           dialogue  \
# 0    test_0  #Person1#: Ms. Dawson, I need you to take a di...
# 1    test_1  #Person1#: You're finally here! What took so l...
# 2    test_2  #Person1#: Kate, you never believe what's happ...
# 3    test_3  #Person1#: Happy Birthday, this is for you, Br...
# 4    test_4  #Person1#: This Olympic park is so big!\n#Pers...
# ..      ...                                                ...
# 95  test_95  #Person1#: Thank you. Steven. That was the mos...
# 96  test_96  #Person1#: Bill, how can you hear so happy tod...
# 97  test_97  #Person1#: I'd like to pay my bill now. \n#Per...
# 98  test_98  #Person1#: Carol telephone.\n#Person2#: Who is...
# 99  test_99  #Person1#: Hey, don't I know you from somewher...
#
#                                               summary
# 0   #Person1# asks Ms. Dawson to take a dictation ...
# 1   #Person2# got stuck in traffic again. #Person1...
# 2   #Person1# tells Kate that Masha and Hero are g...
# 3   #Person1# comes to Brian's birthday party and ...
# 4   #Person2# introduces the Olympic Park to #Pers...
# ..                                                ...
# 95  Steven thanks Lin for the meal he had and asks...
# 96  Bill tells #Person1# he moved because of his r...
# 97  #Person2# helps Tom pay his bill of 660 US dol...
# 98  Susan calls Carol to ask about the time and pl...
# 99  #Person1# thinks she knows #Person2# from some...
#
# [100 rows x 3 columns]
#       fname                                           dialogue  \
# 0    test_0  #Person1#: Ms. Dawson, I need you to take a di...
# 1    test_1  #Person1#: You're finally here! What took so l...
# 2    test_2  #Person1#: Kate, you never believe what's happ...
# 3    test_3  #Person1#: Happy Birthday, this is for you, Br...
# 4    test_4  #Person1#: This Olympic park is so big!\n#Pers...
# ..      ...                                                ...
# 95  test_95  #Person1#: Thank you. Steven. That was the mos...
# 96  test_96  #Person1#: Bill, how can you hear so happy tod...
# 97  test_97  #Person1#: I'd like to pay my bill now. \n#Per...
# 98  test_98  #Person1#: Carol telephone.\n#Person2#: Who is...
# 99  test_99  #Person1#: Hey, don't I know you from somewher...
#
#                                               summary
# 0   #Person1# asks Ms. Dawson to take a dictation ...
# 1   #Person2# got stuck in traffic again because o...
# 2   #Person1# tells Kate that Masha and Hero are g...
# 3   #Person1# comes to Brian's birthday party and ...
# 4   #Person2# tells #Person1# about the Olympic pa...
# ..                                                ...
# 95  Steven is checking the bill and asks Lin about...
# 96  Bill tells #Person1# he's happy today because ...
# 97  #Person2# helps Tom Wilson check out and pay t...
# 98  Susan calls for Carol but she is taking a show...
# 99  #Person1# thinks #Person2# looks familiar and ...
#
# [100 rows x 3 columns]

# %%
# The tuned model did not respond to some prompts due to safety settings
# Let's filter those out of both of our dataframes
filtered_reference_prompts = {}


# {model_name: df}
for dataframe in model_outputs:
    model_name = dataframe
    output_df = model_outputs[dataframe]

    no_response_condition = output_df['summary'].str.contains("FinishReason")
    

    # prompts with no responses
    no_response_prompts = output_df[no_response_condition]
    fnames_to_drop = no_response_prompts['fname'].tolist()

    print(model_name, ' --- ', fnames_to_drop)

    filter_no_reponses =  output_df['fname'].isin(fnames_to_drop)
    
    # Filter out the rows that match the fname from both tables

    model_outputs[model_name] = output_df[~filter_no_reponses]
    filtered_reference_prompts[model_name] = reference_prompts[~filter_no_reponses]
# Out:
# base_gemini  ---  ['test_23', 'test_46', 'test_65', 'test_67']
# vertex_sdk_small  ---  ['test_16', 'test_41']
# vertex_sdk_large  ---  ['test_41']
# vertex_studio_small  ---  ['test_16', 'test_41', 'test_58', 'test_65']
# vertex_studio_large  ---  ['test_30', 'test_41']
# vertex_studio_large_w_validation  ---  ['test_41']

# %%
model_outputs['vertex_sdk_large']
# Out:
#       fname                                           dialogue  \
# 0    test_0  #Person1#: Ms. Dawson, I need you to take a di...
# 1    test_1  #Person1#: You're finally here! What took so l...
# 2    test_2  #Person1#: Kate, you never believe what's happ...
# 3    test_3  #Person1#: Happy Birthday, this is for you, Br...
# 4    test_4  #Person1#: This Olympic park is so big!\n#Pers...
# ..      ...                                                ...
# 95  test_95  #Person1#: Thank you. Steven. That was the mos...
# 96  test_96  #Person1#: Bill, how can you hear so happy tod...
# 97  test_97  #Person1#: I'd like to pay my bill now. \n#Per...
# 98  test_98  #Person1#: Carol telephone.\n#Person2#: Who is...
# 99  test_99  #Person1#: Hey, don't I know you from somewher...
#
#                                               summary
# 0   #Person1# asks Ms. Dawson to take a dictation ...
# 1   #Person2# got stuck in traffic again. #Person1...
# 2   #Person1# tells Kate that Masha and Hero are g...
# 3   #Person1# gives Brian a present on his birthda...
# 4   #Person1# thinks the Olympic park is big. #Per...
# ..                                                ...
# 95  Lin thanks Steven for the magnificent meal. Li...
# 96  Bill tells #Person1# he made a move today and ...
# 97  #Person2# helps Tom Wilson pay his bill with a...
# 98  #Person1# answers the phone for Carol. Carol i...
# 99  #Person1# thinks #Person2# looks familiar and ...
#
# [99 rows x 3 columns]

# %% [markdown]
# ## Run Rouge Evaluation

# %%
predictions_per_model = {}
references_per_model = {}

for dataframe in model_outputs:
  predictions = []
  references = []
  model_name = dataframe
  output_df = model_outputs[dataframe]
  reference_prompts = filtered_reference_prompts[model_name]

  for index, row in output_df.iterrows():
    fname = row['fname']
    dialogue = row['dialogue']
    tuned_summary = row['summary']

    predictions.append(tuned_summary)

    reference_summary_1 = reference_prompts.loc[(reference_prompts['fname'] == fname) & (reference_prompts['dialogue'] == dialogue)]['summary1'].values[0]
    reference_summary_2 = reference_prompts.loc[(reference_prompts['fname'] == fname) & (reference_prompts['dialogue'] == dialogue)]['summary2'].values[0]
    reference_summary_3 = reference_prompts.loc[(reference_prompts['fname'] == fname) & (reference_prompts['dialogue'] == dialogue)]['summary3'].values[0]

    references.append([reference_summary_1, reference_summary_2, reference_summary_3])

    predictions_per_model[model_name] = predictions
    references_per_model[model_name] = references



print(predictions_per_model)
print()
print(references_per_model)
# Out:
# {'base_gemini': ['## Intra-Office Memorandum\n\n**To:** All Employees\n\n**From:** [Your Name]\n\n**Date:** [Date]\n\n**Subject:** Restriction on Instant Messaging Programs\n\n**Effective immediately, all office communications are restricted to email correspondence and official memos.** The use of Instant Message (IM) programs by employees during working hours is strictly prohibited.\n\nThis policy applies to all communications, both internal and external. This means that employees are not allowed to use IM programs to communicate with clients, colleagues, or anyone else outside of the office.\n\nThe use of IM programs can be disruptive and can lead to a loss of productivity. We have found that many employees are spending too much time using IM programs, which is taking away from their work.\n\nWe understand that some employees may use IM programs to communicate with clients. However, there are other ways to communicate with clients, such as email and phone. We encourage employees to use these alternative methods of communication.\n\n**Any employee who persists in using Instant Messaging will first receive a warning and be placed on probation. At second offense, the employee will face termination.**\n\nIf you have any questions about this policy, please contact your department head.\n\nThank you for your cooperation.\n\n**[Your Name]**\n', "#Person1#: I'm glad you've decided to stop driving to work. It's better for the environment and for your health.\n#Person2#: I know, but I'm going to miss the freedom that comes with having a car.\n#Person1#: There are other ways to get around that are just as freeing, like biking or taking the subway.\n#Person2#: I know, but it's not the same.\n#Person1#: Give it some time. You'll get used to it. And you'll be doing your part to help the environment.\n#Person2#: I know, I know. I just need to get over myself.\n#Person1#: You can do it! I believe in you.\n#Person2#: Thanks. I appreciate it.", "#Person2#: Wow, this is a big news. I can't believe that Masha and Hero are getting divorced. I always thought they were such a perfect couple.\n#Person1#: Yeah, it's really surprising. I don't know what happened, but I heard that they've been separated for two months.\n#Person2#: That's a shame. I wonder what will happen to their kids.\n#Person1#: I don't know, but it seems like they're trying to be amicable about it. They haven't been fighting about the house or the money or anything.\n#Person2#: That's good to hear. I hope they can work things out.\n#Person1#: Me too. I'll let you know if I hear anything else.", "#Person2#: Yes, let's go get a drink. I'm so glad you could make it.\n\n(They walk over to the bar and order drinks.)\n\n#Person1#: Cheers to you, Brian. Happy birthday!\n\n#Person2#: Cheers to you too. I'm so happy you're here.\n\n(They clink glasses and take a sip of their drinks.)\n\n#Person1#: This is a really great party. You've done a great job.\n\n#Person2#: Thanks, I'm glad you like it. I've been looking forward to it all week.\n\n#Person1#: I can tell. You look amazing.\n\n#Person2#: Thanks, you too.\n\n(They continue to chat and enjoy their drinks.)\n\n#Person1#: I should probably get going soon. I don't want to overstay my welcome.\n\n#Person2#: Oh, okay. Well, thanks for coming. I really appreciate it.\n\n#Person1#: No problem. I had a great time.\n\n(They hug goodbye.)\n\n#Person2#: See you later.\n\n#Person1#: Bye.", '#Person1#: Wow, this Olympic park is huge!\n#Person2#: Yes, it is. We are now standing in the Olympic stadium, the centerpiece of the park.\n#Person1#: It\'s magnificent! When will it be completed?\n#Person2#: The entire stadium is scheduled to be finished this June.\n#Person1#: How many seats are there in the stands?\n#Person2#: There are a total of 5,000 seats.\n#Person1#: I had no idea it would be this big!\n#Person2#: It certainly is! Look over there, those are the tracks. And the jumping pit is over there.\n#Person1#: Ah, I see. Hey, look at the sign here,  ...
#
# {'base_gemini': [['Ms. Dawson helps #Person1# to write a memo to inform every employee that they have to change the communication method and should not use Instant Messaging anymore.', 'In order to prevent employees from wasting time on Instant Message programs, #Person1# decides to terminate the use of those programs and asks Ms. Dawson to send out a memo to all employees by the afternoon.', 'Ms. Dawson takes a dictation for #Person1# about prohibiting the use of Instant Message programs in the office. They argue about its reasonability but #Person1# still insists.'], ['#Person2# arrives late because of traffic jam. #Person1# persuades #Person2# to use public transportations to keep healthy and to protect the environment.', "#Person2# decides to follow #Person1#'s suggestions on quitting driving to work and will try to use public transportations.", '#Person2# complains to #Person1# about the traffic jam, #Person1# suggests quitting driving and taking public transportation instead.'], ['#Person1# tells Kate that Masha and Hero get divorced. Kate is surprised because she thought they are perfect couple.', '#Person1# tells Kate that Masha and Hero are getting a peaceful divorce. Kate feels surprised and asks about their kids.', '#Person1# and Kate talk about the divorce between Masha and Hero. Kate feels surprised because she thought they are well matched'], ['#Person1# and Brian are at the birthday party of Brian. Brian thinks #Person1# looks great and is popular.', "#Person1# attends Brian's birthday party. Brian thinks #Person1# looks great and charming.", "#Person1# has a dance with Brian at Brian's birthday party. Brian thinks #Person1# looks great and is popular."], ["#Person1# is surprised at the Olympic Stadium'volume, capacity and interior setting to #Person1#.", '#Person2# shows #Person1# around the constructing Olympic stadium and introduces the stadium.', "#Person2# introduces the Olympic Stadium's finishing time, capacity and interior setting to #Person1#."], ['#Person1# wants to create a company and is going to write a business plan. #Person2# gives #Person1# suggestions on how to summarise business ideas, describe the service, differ from competitors and attract investment in a good business plan. #Person1# decides to stick to the old job.', '#Person1# abandons the idea of creating a company after #Person2# explains what a business plan includes. #Person2# specifies that a well-written business plan includes an executive summary, goods and service description, strategy and implementation, and financial analysis.', "#Person1# wants to start #Person1#'s own business, but #Person2# warns #Person1# of the hassle. #Person2# tells #Person1# what is needed in a business plan and #Person1# decides to stick to the old job for now."], ["#Person2# feels itchy. #Person1# doubts it is chicken pox and asks #Person2# to get away. #Person2# doesn't believe it.", '#Person1# suspects that #Person2# has chicken pox and wants to keep away from #Person2#. #Person2# thinks #Person1# is exaggerating.', '#Person1# thinks #Person2# has chicken pox and warns #Person2# about the possible hazards but #Person2# thinks it will be fine.'], ['#Person2# is checking out and asks #Person1# for the bill. #Person1# gives #Person2# a wrong bill at first then corrects it.', '#Person1# helps #Person2# correct a mischarged bill on laundry service and helps #Person2# check out.', '#Person2# finds #Person2# being mischarged. #Person1# corrects the bill and #Person2# pays for it.'], ['#Person1# is begging Steven to persuade his wife not to divorce him. Steven agrees.', "Steve will try to persuade #Person1#'s wife not to divorce #Person1# as #Person1# swears to remain faithful forever.", "#Person1# begs Steven's to persuade #Person1#'s wife not to divorce him, and Steven agrees."], ['#Person1# and #Person2# are talking about Abraham Lincoln. They think he was a noble man.', '#Person2# admires Abraham Lincoln for his perseverance, courage and humility.', '#Pe ...

# %%
scores = {}
# Score all prompts against 3 reference responses for one score

for dataframe in model_outputs:
    model_name = dataframe
    score = rouge.compute(
            predictions=predictions_per_model[model_name],
            references=references_per_model[model_name])
    
    scores[model_name] = score

for model in scores:
    print(model, ' --- ', scores[model])
# Out:
# base_gemini  ---  {'rouge1': 0.16186534895209137, 'rouge2': 0.0453878111544593, 'rougeL': 0.12434220411396402, 'rougeLsum': 0.1418452796600015}
# vertex_sdk_small  ---  {'rouge1': 0.5267998115442215, 'rouge2': 0.28331536887828446, 'rougeL': 0.4583534222474014, 'rougeLsum': 0.457816011742501}
# vertex_sdk_large  ---  {'rouge1': 0.5441469911506053, 'rouge2': 0.29809703686987343, 'rougeL': 0.47148420181215894, 'rougeLsum': 0.47011074167228645}
# vertex_studio_small  ---  {'rouge1': 0.5282531249662937, 'rouge2': 0.26570070727725426, 'rougeL': 0.4463253283804182, 'rougeLsum': 0.4458456416613107}
# vertex_studio_large  ---  {'rouge1': 0.5572866925825298, 'rouge2': 0.3126900180712632, 'rougeL': 0.4863236624057099, 'rougeLsum': 0.4860592699994632}
# vertex_studio_large_w_validation  ---  {'rouge1': 0.554393529256747, 'rouge2': 0.3059111890892891, 'rougeL': 0.47734949923656433, 'rougeLsum': 0.47747216614091803}
